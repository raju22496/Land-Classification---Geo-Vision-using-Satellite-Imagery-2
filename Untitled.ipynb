# %%
# !pip install torch
# Out:
# Requirement already satisfied: torch in c:\users\sande\appdata\local\programs\python\python311\lib\site-packages (2.2.2)
# Requirement already satisfied: filelock in c:\users\sande\appdata\local\programs\python\python311\lib\site-packages (from torch) (3.12.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\sande\appdata\local\programs\python\python311\lib\site-packages (from torch) (4.9.0)
# Requirement already satisfied: sympy in c:\users\sande\appdata\local\programs\python\python311\lib\site-packages (from torch) (1.12)
# Requirement already satisfied: networkx in c:\users\sande\appdata\local\programs\python\python311\lib\site-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in c:\users\sande\appdata\local\programs\python\python311\lib\site-packages (from torch) (3.1.2)
# Requirement already satisfied: fsspec in c:\users\sande\appdata\local\programs\python\python311\lib\site-packages (from torch) (2024.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\sande\appdata\local\programs\python\python311\lib\site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in c:\users\sande\appdata\local\programs\python\python311\lib\site-packages (from sympy->torch) (1.3.0)

# %%
import os
import cv2
import torch
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import pytorch_lightning as pl
from torch import nn
from tqdm.notebook import tqdm
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 3
#       1 import os
#       2 import cv2
# ----> 3 import torch
#       4 import numpy as np
#       5 import pandas as pd
#
# ModuleNotFoundError: No module named 'torch'
